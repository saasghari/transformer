# %% [markdown]
# # **Transformer**
# ##### Transformer with python. This project is written in Python to learn and test Transformers with Keras.
# ###### We write program in local jypyter notebook in VSCode. Then push it to a github repository. Finally we run our program on google colab.

# %%
print("Hello!")
print("Welcome to my program")
# Out:
# Hello!
# Welcome to my program
